# %%
import pandas as pd

# %%
import numpy as  np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
df= pd.read_csv('Boston.csv')

# %%
df
# Out:
#         CRIM   ZN   INDUS   CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0    2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0    7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0    7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0    2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0    2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...     ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0   11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0   11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0   11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0   11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0   11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO  LSTAT  MEDV
# 0       15.3   4.98  24.0
# 1       17.8   9.14  21.6
# 2       17.8   4.03  34.7
# ...

# %%
df.isnull().sum()
# Out:
# CRIM       0
#  ZN        0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
df.shape
# Out:
# (436, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1    ZN      506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  LSTAT    506 non-null    float64
#  12  MEDV     506 non-null    float64
# dtypes: float64(10), int64(3)
# memory usage: 51.5 KB

# %%
sns.pairplot(df)

# %%
print (list(df.columns))
# Out:
# ['CRIM', ' ZN ', 'INDUS ', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'LSTAT', 'MEDV']

# %%
df.describe()
# Out:
#              CRIM         ZN       INDUS         CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO       LSTAT  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534   12.653063
# ...

# %%
sns.boxplot(df['CRIM'])

# %%
sns.distplot(df['CRIM'])

# %%
from scipy import stats

# %%
z = np.abs(stats.zscore(df))
print(z)
# Out:
# [[0.41978194 0.28482986 1.2879095  ... 1.45900038 1.0755623  0.15968566]
#  [0.41733926 0.48772236 0.59338101 ... 0.30309415 0.49243937 0.10152429]
#  [0.41734159 0.48772236 0.59338101 ... 0.30309415 1.2087274  1.32424667]
#  ...
#  [0.41344658 0.48772236 0.11573841 ... 1.17646583 0.98304761 0.14880191]
#  [0.40776407 0.48772236 0.11573841 ... 1.17646583 0.86530163 0.0579893 ]
#  [0.41500016 0.48772236 0.11573841 ... 1.17646583 0.66905833 1.15724782]]

# %%
threshold = 3
print(np.where(z > 3))
# Out:
# (array([ 55,  56,  57, 141, 142, 152, 154, 155, 160, 162, 163, 199, 200,
#        201, 202, 203, 204, 208, 209, 210, 211, 212, 216, 218, 219, 220,
#        221, 222, 225, 234, 236, 256, 257, 262, 269, 273, 274, 276, 277,
#        282, 283, 283, 284, 347, 351, 352, 353, 353, 354, 355, 356, 357,
#        358, 363, 364, 364, 365, 367, 369, 370, 372, 373, 374, 374, 380,
#        398, 404, 405, 406, 410, 412, 414, 414, 418, 427], dtype=int32), array([ 1,  1,  1, 11,  3,  3,  3,  3,  3,  3,  3,  1,  1,  1,  1,  1,  1,
#         3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  5,  3,  3,  1,  5,  5,
#         3,  3,  3,  3,  3,  3,  1,  3,  1,  1,  7,  7,  1,  7,  7,  7,  3,
#         3,  3,  3,  3,  5,  5,  5,  3,  3,  3, 11,  5, 11,  0,  0,  0,  0,
#         5,  0, 11,  0, 11,  0,  0], dtype=int32))

# %%
df = df[(z < 3).all(axis=1)]

# %%
from sklearn.preprocessing import StandardScaler

# %%
min= StandardScaler()

# %%
min.fit_transform(df)
# Out:
# array([[-0.54783216,  0.4594424 , -1.30148947, ..., -1.53641508,
#         -1.15566088,  0.26111362],
#        [-0.5437393 , -0.47395236, -0.60131963, ..., -0.35564061,
#         -0.5330952 , -0.03114148],
#        [-0.5437432 , -0.47395236, -0.60131963, ..., -0.35564061,
#         -1.29783334,  1.56408426],
#        ...,
#        [-0.53721686, -0.47395236,  0.11355966, ...,  1.15575073,
#         -1.05688845,  0.24893632],
#        [-0.52769545, -0.47395236,  0.11355966, ...,  1.15575073,
#         -0.93117807,  0.0175677 ],
#        [-0.53981999, -0.47395236,  0.11355966, ...,  1.15575073,
#         -0.72166077, -1.21233916]])

# %%
df
# Out:
#         CRIM   ZN   INDUS   CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0    2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0    7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0    7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0    2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0    2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...     ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0   11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0   11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0   11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0   11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0   11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO  LSTAT  MEDV
# 0       15.3   4.98  24.0
# 1       17.8   9.14  21.6
# 2       17.8   4.03  34.7
# ...

# %%
sns.distplot(df['CRIM'])

# %%
df.columns
# Out:
# Index(['CRIM', ' ZN ', 'INDUS ', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
for i, col in enumerate(df.columns):
    plt.figure(i)
    sns.boxplot(x=col, data=df)

# %%
(df['LSTAT']>35).value_counts()
# Out:
# False    436
# Name: LSTAT, dtype: int64

# %%
(df['MEDV']>35).value_counts()
# Out:
# False    404
# True      32
# Name: MEDV, dtype: int64

# %%
correlation=df.corr()

# %%
correlation
# Out:
#              CRIM       ZN     INDUS   CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.251348  0.523520   NaN  0.569795 -0.230036  0.439099
#  ZN     -0.251348  1.000000 -0.490184   NaN -0.489119  0.279295 -0.513772
# INDUS    0.523520 -0.490184  1.000000   NaN  0.745328 -0.378926  0.609581
# CHAS          NaN       NaN       NaN   NaN       NaN       NaN       NaN
# NOX      0.569795 -0.489119  0.745328   NaN  1.000000 -0.291320  0.723347
# RM      -0.230036  0.279295 -0.378926   NaN -0.291320  1.000000 -0.206635
# AGE      0.439099 -0.513772  0.609581   NaN  0.723347 -0.206635  1.000000
# DIS     -0.483735  0.607413 -0.686802   NaN -0.775233  0.186039 -0.726084
# RAD      0.810953 -0.283157  0.579813   NaN  0.609623 -0.152461  0.426654
# TAX      0.751569 -0.294879  0.717119   NaN  0.667432 -0.245837  0.492691
# PTRATIO  0.349927 -0.410910  0.384020   NaN  0.193702 -0.298978  0.263418
# LSTAT    0.587798 -0.384739  0.619506   NaN  0.627257 -0.584952  0.611677
# ...

# %%
print (correlation>=0.6)
# Out:
#           CRIM    ZN   INDUS    CHAS    NOX     RM    AGE    DIS    RAD  \
# CRIM      True  False   False  False  False  False  False  False   True
#  ZN      False   True   False  False  False  False  False   True  False
# INDUS    False  False    True  False   True  False   True  False  False
# CHAS     False  False   False  False  False  False  False  False  False
# NOX      False  False    True  False   True  False   True  False   True
# RM       False  False   False  False  False   True  False  False  False
# AGE      False  False    True  False   True  False   True  False  False
# DIS      False   True   False  False  False  False  False   True  False
# RAD       True  False   False  False   True  False  False  False   True
# TAX       True  False    True  False   True  False  False  False   True
# PTRATIO  False  False   False  False  False  False  False  False  False
# LSTAT    False  False    True  False   True  False   True  False  False
# ...

# %%
sns.heatmap(correlation)

# %%
import statsmodels.formula.api as smf
from sklearn.model_selection import train_test_split

# %%
X = df.drop('CRIM' , axis=1)
y=df[['CRIM']]

# %%
X_train , y_train , X_test , y_test = train_test_split(X,y, test_size=0.3 , random_state=0)

# %%
train_data= pd.concat([X_train,y_train] , axis = 1)

# %%
test_data = pd.concat([X_test , y_test] , axis=1 )

# %%
sns.regplot(x='MEDV' , y= 'CRIM' , data=df)

# %%
y = np.log(df['CRIM'])

# %%
sns.regplot(x=df['MEDV'] , y=y)

# %%
train_data
# Out:
#       ZN   INDUS   CHAS    NOX     RM   AGE     DIS  RAD    TAX  PTRATIO  ...  \
# 0    18.0    2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0     15.3  ...
# 1     NaN     NaN   NaN    NaN    NaN   NaN     NaN  NaN    NaN      NaN  ...
# 2     0.0    7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0     17.8  ...
# 3     0.0    2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0     18.7  ...
# 4     NaN     NaN   NaN    NaN    NaN   NaN     NaN  NaN    NaN      NaN  ...
# ..    ...     ...   ...    ...    ...   ...     ...  ...    ...      ...  ...
# 501   NaN     NaN   NaN    NaN    NaN   NaN     NaN  NaN    NaN      NaN  ...
# 502   NaN     NaN   NaN    NaN    NaN   NaN     NaN  NaN    NaN      NaN  ...
# 503   0.0   11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0     21.0  ...
# 504   0.0   11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0     21.0  ...
# 505   0.0   11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0     21.0  ...
#
# ...

# %%
multilinearmodel = smf.ols(formula='CRIM ~ LSTAT + RAD ' , data = df)
result = multilinearmodel.fit()

# %%
print (result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   CRIM   R-squared:                       0.701
# Model:                            OLS   Adj. R-squared:                  0.700
# Method:                 Least Squares   F-statistic:                     508.0
# Date:                Sun, 04 Oct 2020   Prob (F-statistic):          2.72e-114
# Time:                        07:33:48   Log-Likelihood:                -1068.1
# No. Observations:                 436   AIC:                             2142.
# Df Residuals:                     433   BIC:                             2154.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -3.3898      0.290    -11.683      0.000      -3.960      -2.819
# ...

# %%
linear = smf.ols(formula = 'np.log(CRIM)  ~ MEDV' , data=df)

# %%
result = linear.fit()

# %%
print (result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           np.log(CRIM)   R-squared:                       0.223
# Model:                            OLS   Adj. R-squared:                  0.221
# Method:                 Least Squares   F-statistic:                     124.3
# Date:                Sun, 04 Oct 2020   Prob (F-statistic):           1.49e-25
# Time:                        07:35:30   Log-Likelihood:                -879.39
# No. Observations:                 436   AIC:                             1763.
# Df Residuals:                     434   BIC:                             1771.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.7654      0.248      7.113      0.000       1.278       2.253
# ...
